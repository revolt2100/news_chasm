# %%
import pandas as pd

# %%
ds = pd.read_json('updated_holod_data.json')

# %%
ds[['article_images_overall_score', 'text_overall_score']].corr()
# Out:
#                               article_images_overall_score  text_overall_score
# article_images_overall_score                      1.000000            0.341732
# text_overall_score                                0.341732            1.000000

# %%
ds.plot.scatter(x='article_images_overall_score', y='text_overall_score')
# Out:
# <Axes: xlabel='article_images_overall_score', ylabel='text_overall_score'>

# %%
ds.plot.scatter(x='article_images_overall_score', y='text_overall_score')
